# %% [markdown]
# <a href="https://colab.research.google.com/github/yogeshgujjar/hero-no-1/blob/main/customer_churn_prediction_using_ann_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Churn_Modelling.csv")

# %%
df.head(3)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1

# %%
drop_cols = ['RowNumber','CustomerId','Surname','Geography','Gender']
df.drop(drop_cols,axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1

# %%
input_data = df.iloc[:,:-1]
output_data = df.iloc[:,-1]

# %%
ss = StandardScaler()
input_data = pd.DataFrame(ss.fit_transform(input_data),columns=input_data.columns)

# %%
input_data.head(3)
# Out:
#    CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0    -0.326221  0.293517 -1.041760 -1.225848      -0.911583   0.646092
# 1    -0.440036  0.198164 -1.387538  0.117350      -0.911583  -1.547768
# 2    -1.536794  0.293517  1.032908  1.333053       2.527057   0.646092
#
#    IsActiveMember  EstimatedSalary
# 0        0.970243         0.021886
# 1        0.970243         0.216534
# 2       -1.030670         0.240687

# %%
input_data.shape
# Out:
# (10000, 8)

# %%
x_train,x_test,y_train,y_test = train_test_split(input_data,output_data,test_size=0.2,random_state=10)

# %%
x_train.shape
# Out:
# (8000, 8)

# %%
x_test
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 937      2.063884  0.484225 -0.004426  0.835324      -0.911583  -1.547768
# 9355     0.915392  0.102810  1.032908 -1.225848      -0.911583   0.646092
# 2293     0.398053  0.579578 -1.733315 -0.299734      -0.911583   0.646092
# 192     -1.774770  0.102810 -1.387538 -1.225848       0.807737  -1.547768
# 8675     0.656722  1.437761  0.687130  0.795384      -0.911583   0.646092
# ...           ...       ...       ...       ...            ...        ...
# 5624    -0.346915  0.579578 -1.387538 -1.225848      -0.911583   0.646092
# 6005    -0.150326 -1.422847  1.378686 -1.225848       0.807737  -1.547768
# 987     -0.843560 -0.469311 -1.733315  1.207697      -0.911583   0.646092
# 6152    -1.474714  2.391296 -1.041760 -1.225848      -0.911583   0.646092
# 2092     0.046263 -0.087897 -0.695982  2.795323       2.527057  -1.547768
#
#       IsActiveMember  EstimatedSalary
# 937         0.970243         1.234723
# 9355       -1.030670         1.164024
# 2293       -1.030670         1.699145
# 192        -1.030670         0.259204
# 8675       -1.030670         0.220617
# ...              ...              ...
# 5624       -1.030670         0.751341
# 6005        0.970243        -1.065242
# 987        -1.030670         0.038422
# 6152        0.970243        -1.634803
# 2092        0.970243        -0.331021
#
# [2000 rows x 8 columns]

# %%
import tensorflow

# %%
from keras.layers import Dense,BatchNormalization, Dropout
from keras.callbacks import EarlyStopping
from keras.models import Sequential

# %%
ann = Sequential()

# %%
ann.add(Dense(6,input_dim = 8,activation="relu",kernel_regularizer=l2(l2=0.01)))
ann.add(Dropout(0.5))
#ann.add(BatchNormalization())
ann.add(Dense(4,activation="relu",kernel_regularizer=l2(l2=0.01)))
ann.add(Dropout(0.5))
#ann.add(BatchNormalization())
ann.add(Dense(2,activation="relu",kernel_regularizer=l2(l2=0.01)))
ann.add(Dropout(0.5))
#ann.add(BatchNormalization())
ann.add(Dense(1,activation="sigmoid"))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
ann.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
ann.fit(x_train,y_train, batch_size=100,epochs=40,validation_data=(x_test,y_test),callbacks = EarlyStopping())
# Out:
# Epoch 1/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7520 - loss: 0.8706 - val_accuracy: 0.7715 - val_loss: 0.7437
# Epoch 2/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7696 - loss: 0.7903 - val_accuracy: 0.7885 - val_loss: 0.6947
# Epoch 3/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7957 - loss: 0.7041 - val_accuracy: 0.7890 - val_loss: 0.6556
# Epoch 4/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7982 - loss: 0.6660 - val_accuracy: 0.7890 - val_loss: 0.6222
# Epoch 5/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7943 - loss: 0.6415 - val_accuracy: 0.7890 - val_loss: 0.5978
# Epoch 6/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8020 - loss: 0.6025 - val_accuracy: 0.7890 - val_loss: 0.5776
# Epoch 7/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7934 - loss: 0.5954 - val_accuracy: 0.7890 - val_loss: 0.5649
# Epoch 8/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8024 - loss: 0.5691 - val_accuracy: 0.7890 - val_loss: 0.5548
# Epoch 9/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7949 - loss: 0.5744 - val_accuracy: 0.7890 - val_loss: 0.5483
# Epoch 10/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7938 - loss: 0.5614 - val_accuracy: 0.7890 - val_loss: 0.5427
# Epoch 11/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8054 - loss: 0.5400 - val_accuracy: 0.7890 - val_loss: 0.5378
# Epoch 12/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7966 - loss: 0.5478 - val_accuracy: 0.7890 - val_loss: 0.5342
# Epoch 13/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8067 - loss: 0.5324 - val_accuracy: 0.7890 - val_loss: 0.5316
# Epoch 14/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7982 - loss: 0.5372 - val_accuracy: 0.7890 - val_loss: 0.5294
# Epoch 15/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8070 - loss: 0.5216 - val_accuracy: 0.7890 - val_loss: 0.5275
# Epoch 16/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8046 - loss: 0.5200 - val_accuracy: 0.7890 - val_loss: 0.5254
# Epoch 17/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8081 - loss: 0.5148 - val_accuracy: 0.7890 - val_loss: 0.5241
# Epoch 18/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7921 - loss: 0.5291 - val_accuracy: 0.7890 - val_loss: 0.5228
# Epoch 19/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7923 - loss: 0.5246 - val_accuracy: 0.7890 - val_loss: 0.5214
# Epoch 20/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8018 - loss: 0.5132 - val_accuracy: 0.7890 - val_loss: 0.5204
# Epoch 21/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7992 - loss: 0.5143 - val_accuracy: 0.7890 - val_loss: 0.5195
# Epoch 22/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7949 - loss: 0.5180 - val_accuracy: 0.7890 - val_loss: 0.5188
# Epoch 23/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7943 - loss: 0.5198 - val_accuracy: 0.7890 - val_loss: 0.5184
# Epoch 24/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7940 - loss: 0.5148 - val_accuracy: 0.7890 - val_loss: 0.5177
# Epoch 25/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7938 - loss: 0.5161 - val_accuracy: 0.7890 - val_loss: 0.5173
# Epoch 26/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7927 - loss: 0.5159 - val_accuracy: 0.7890 - val_loss: 0.5168
# Epoch 27/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7966 - loss: 0.5101 - val_accuracy: 0.7890 - val_loss: 0.5165
# Epoch 28/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7974 - loss: 0.5077 - val_accuracy: 0.7890 - val_loss: 0.5162
# Epoch 29/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7974 - loss: 0.5064 - val_accuracy: 0.7890 - val_loss: 0.5160
# Epoch 30/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8042 - loss: 0.4978 - val_accuracy: 0.7890 - val_loss: 0.5158
# Epoch 31/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8005 - loss: 0.5011 - val_accuracy: 0.7890 - val_loss: 0.5156
# Epoch 32/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7965 - loss: 0.5087 - val_accuracy: 0.7890 - val_loss: 0.5155
# Epoch 33/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7987 - loss: 0.5047 - val_accuracy: 0.7890 - val_loss: 0.5154
# Epoch 34/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8017 - loss: 0.4992 - val_accuracy: 0.7890 - val_loss: 0.5153
# Epoch 35/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8006 - loss: 0.5006 - val_accuracy: 0.7890 - val_loss: 0.5152
# Epoch 36/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8010 - loss: 0.5013 - val_accuracy: 0.7890 - val_loss: 0.5151
# Epoch 37/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7955 - loss: 0.5085 - val_accuracy: 0.7890 - val_loss: 0.5152

# %%
train_accuracy = ann.history.history["accuracy"]
test_accuracy = ann.history.history["val_accuracy"]

# %%
plt.plot([i for i in range(1, len(train_accuracy) + 1)],train_accuracy)
plt.plot([i for i in range(1, len(train_accuracy) + 1)],test_accuracy,c='red')
plt.show()

# %%
#plt.plot([i for i in range(1,6)],train_accuracy)
#plt.plot([i for i in range(1,6)],test_accuracy,c='red')
#plt.show()

# %%
prd1 = ann.predict(x_train)
prd_data1 = []
for i in prd1:
  if i[0] > 0.5 :
    prd_data1.append(1)
  else:
    prd_data1.append(0)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
prd = ann.predict(x_test)
prd_data = []
for i in prd:
  if i[0] > 0.5 :
    prd_data.append(1)
  else:
    prd_data.append(0)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
#prd_data

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,prd_data)*100
# Out:
# 78.9

# %%
accuracy_score(y_train,prd_data1)*100
# Out:
# 79.8125

# %%
import numpy as np

# Input data ko numpy array me convert karo
x_input = np.array([[-0.564197, -0.660018, -0.695982, 0.324119, 0.807737, -1.547768, -1.030670, -1.013811]])

# Prediction lo
prd = ann.predict(x_input)

# Prediction process
prd_data = []
for i in prd:
    if i[0] > 0.5:
        prd_data.append(1)
    else:
        prd_data.append(0)

print(prd_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# [0]

# %%
y_test
# Out:
# 937     0
# 9355    0
# 2293    1
# 192     0
# 8675    0
#        ..
# 5624    0
# 6005    0
# 987     1
# 6152    0
# 2092    1
# Name: Exited, Length: 2000, dtype: int64
