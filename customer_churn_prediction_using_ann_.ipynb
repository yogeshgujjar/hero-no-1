# %% [markdown]
# <a href="https://colab.research.google.com/github/yogeshgujjar/hero-no-1/blob/main/customer_churn_prediction_using_ann_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/content/Churn_Modelling.csv")

# %%
df.head(3)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1

# %%
drop_cols = ['RowNumber','CustomerId','Surname','Geography','Gender']
df.drop(drop_cols,axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1

# %%
input_data = df.iloc[:,:-1]
output_data = df.iloc[:,-1]

# %%
ss = StandardScaler()
input_data = pd.DataFrame(ss.fit_transform(input_data),columns=input_data.columns)

# %%
input_data.head(3)
# Out:
#    CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0    -0.326221  0.293517 -1.041760 -1.225848      -0.911583   0.646092
# 1    -0.440036  0.198164 -1.387538  0.117350      -0.911583  -1.547768
# 2    -1.536794  0.293517  1.032908  1.333053       2.527057   0.646092
#
#    IsActiveMember  EstimatedSalary
# 0        0.970243         0.021886
# 1        0.970243         0.216534
# 2       -1.030670         0.240687

# %%
input_data.shape
# Out:
# (10000, 8)

# %%
x_train,x_test,y_train,y_test = train_test_split(input_data,output_data,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (8000, 8)

# %%
x_test
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 6252    -0.564197 -0.660018 -0.695982  0.324119       0.807737  -1.547768
# 4684    -0.284834  0.388871 -1.387538 -1.225848       0.807737   0.646092
# 1731    -0.512463  0.484225 -0.350204 -1.225848       0.807737   0.646092
# 4742    -1.495407  1.914528  1.032908  0.683816       0.807737   0.646092
# 4521    -0.936681 -1.136786  0.687130  0.777477      -0.911583   0.646092
# ...           ...       ...       ...       ...            ...        ...
# 6412    -0.502117  1.342407 -0.004426  0.349118      -0.911583  -1.547768
# 8285    -0.429689 -1.327494  1.724464 -1.225848      -0.911583  -1.547768
# 7853     0.822271  0.770285  0.687130 -1.225848      -0.911583   0.646092
# 1095     0.429093 -0.946079 -0.350204 -1.225848      -0.911583   0.646092
# 6929    -0.233100  0.007457 -1.387538  0.622738      -0.911583   0.646092
#
#       IsActiveMember  EstimatedSalary
# 6252       -1.030670        -1.013811
# ...

# %%
import tensorflow

# %%
from keras.layers import Dense
from keras.models import Sequential

# %%
ann = Sequential()

# %%
ann.add(Dense(6,input_dim = 8,activation="relu"))
ann.add(Dense(4,activation="relu"))
ann.add(Dense(2,activation="relu"))
ann.add(Dense(1,activation="sigmoid"))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
ann.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
ann.fit(x_train,y_train, batch_size=100,epochs=50)
# Out:
# Epoch 1/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7865 - loss: 0.4380
# Epoch 2/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7928 - loss: 0.4302
# Epoch 3/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7951 - loss: 0.4291
# Epoch 4/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8116 - loss: 0.4263
# Epoch 5/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8233 - loss: 0.4232
# Epoch 6/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8248 - loss: 0.4275
# Epoch 7/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8293 - loss: 0.4192
# Epoch 8/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8296 - loss: 0.4207
# Epoch 9/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8327 - loss: 0.4160
# Epoch 10/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8265 - loss: 0.4285
# Epoch 11/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8308 - loss: 0.4172
# Epoch 12/50
# ...

# %%
prd1 = ann.predict(x_train)
prd_data1 = []
for i in prd1:
  if i[0] > 0.5 :
    prd_data1.append(1)
  else:
    prd_data1.append(0)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
prd = ann.predict(x_test)
prd_data = []
for i in prd:
  if i[0] > 0.5 :
    prd_data.append(1)
  else:
    prd_data.append(0)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
#prd_data

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,prd_data)*100
# Out:
# 85.25

# %%
accuracy_score(y_train,prd_data1)*100
# Out:
# 84.8875

# %%
import numpy as np

# Input data ko numpy array me convert karo
x_input = np.array([[-0.564197, -0.660018, -0.695982, 0.324119, 0.807737, -1.547768, -1.030670, -1.013811]])

# Prediction lo
prd = ann.predict(x_input)

# Prediction process
prd_data = []
for i in prd:
    if i[0] > 0.5:
        prd_data.append(1)
    else:
        prd_data.append(0)

print(prd_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [0]

# %%
y_test
# Out:
# 6252    0
# 4684    0
# 1731    0
# 4742    0
# 4521    0
#        ..
# 6412    1
# 8285    0
# 7853    1
# 1095    1
# 6929    1
# Name: Exited, Length: 2000, dtype: int64
